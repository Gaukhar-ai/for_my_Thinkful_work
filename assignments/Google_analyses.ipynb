# %%
#!pip install pandas_datareader
# Out:
# Collecting pandas_datareader
# WARNING: You are using pip version 20.2; however, version 20.2.3 is available.
# You should consider upgrading via the 'c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\python.exe -m pip install --upgrade pip' command.
#   Downloading pandas_datareader-0.9.0-py3-none-any.whl (107 kB)
# Requirement already satisfied: pandas>=0.23 in c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages (from pandas_datareader) (1.0.5)
# Requirement already satisfied: requests>=2.19.0 in c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages (from pandas_datareader) (2.24.0)
# Requirement already satisfied: lxml in c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages (from pandas_datareader) (4.5.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages (from pandas>=0.23->pandas_datareader) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.19.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\gaukharjavarova\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.6.1->pandas>=0.23->pandas_datareader) (1.13.0)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.9.0

# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt

# %%
start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2020, 9, 5)

# %%
google = web.DataReader('GOOGL', 'yahoo', start, end)

# %%
google.head()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1368.680054  1346.489990  1348.410034  1368.680054  1363900
# 2020-01-03  1373.750000  1347.319946  1348.000000  1361.520020  1170400
# 2020-01-06  1398.319946  1351.000000  1351.630005  1397.810059  2338400
# 2020-01-07  1403.500000  1391.560059  1400.459961  1395.109985  1716500
# 2020-01-08  1411.849976  1392.630005  1394.819946  1405.040039  1765700
#
#               Adj Close
# Date
# 2020-01-02  1368.680054
# 2020-01-03  1361.520020
# 2020-01-06  1397.810059
# 2020-01-07  1395.109985
# 2020-01-08  1405.040039

# %%
google['Open'].plot(label = 'GOOGL Open price', figsize = (15, 8))
google['Close'].plot(label = 'GOOGL Close price')
google['High'].plot(label = 'GOOGL High price')
google['Low'].plot(label = 'GOOGL Low price')
plt.legend()
plt.title('Google Stock Prices')
plt.ylabel('Stock Price')
plt.xlabel('Date')
plt.show()
# Out:
# c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)

# %%
google['Volume'].plot(figsize = (15, 5))
plt.title('Volume Traded by Google')
# Out:
# c:\users\gaukharjavarova\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\converter.py:256: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
# Text(0.5, 1.0, 'Volume Traded by Google')
