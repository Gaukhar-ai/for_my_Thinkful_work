# %%
import requests
import pandas as pd

# %%
#load the stock symbols into a data frame. 
df = pd.read_csv('')
df.head()
# Out:
#       beta  bookValuePerShare  currentRatio  divGrowthRate3Year  \
# 0  1.21802            2.79895       1.31538                 0.0
# 1  2.35784            0.00000      18.20330                 0.0
# 2  0.85623           31.06079       3.46119                 0.0
# 3  0.66686            0.00000       6.23734                 0.0
# 4  0.94418            0.00000       0.00000                 0.0
#
#    dividendAmount           dividendDate  dividendPayAmount  \
# 0        3.080000  2019-05-10 00:00:00.0           0.770000
# 1        0.000000                    NaN           0.000000
# 2        0.000000                    NaN           0.000000
# 3        0.000000                    NaN           0.000000
# 4        1.338665  2019-06-17 00:00:00.0           0.411154
#
#          dividendPayDate  dividendYield  epsChange  ...  revChangeYear  \
# 0  2019-08-16 00:00:00.0           1.57        0.0  ...            0.0
# 1                    NaN           0.00        0.0  ...            0.0
# ...
