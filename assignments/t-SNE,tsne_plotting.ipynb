# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
mnist = fetch_openml('Fashion-MNIST', version=1, cache=True)

# %%
np.random.seed(55)
#select 10K images randomly
indices = np.random.choice(50000, 10000)
X = mnist.data[indices]/255.0
y = mnist.target[indices]

print(X.shape, y.shape)                         #ask about this
# Out:
# (10000, 784) (10000,)

# %%
#t-SNE with n_components = 2.

tsne = TSNE(n_components = 2, verbose=1, perplexity=40, n_iter=250)
tsne_results = tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 6.542s...
# [t-SNE] Computed neighbors for 10000 samples in 301.552s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.851024
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.461807
# [t-SNE] KL divergence after 251 iterations: .000000

# %% [markdown]
# use 2 dimensional t-SNE representation, draw a graph of the data by coloring and labeling the data points as done in the checkpoint

# %%
plt.figure(figsize=(10,5))
colours = ["r","b","g","c","m","y","k","r","burlywood","chartreuse"]
for i in range(tsne_results.shape[0]):
    plt.text(tsne_results[i, 0], tsne_results[i, 1], str(y[i]),
             color=colours[int(y[i])],
             fontdict={'weight': 'bold', 'size': 50}
        )

plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.show()

# %% [markdown]
# plt.figure(figsize=(10,5))
# colours = ['r', 'b', 'g', 'c', 'm', 'y', 'k', 'r', 'burlywood', 'chartreuse']
# for i in range(tsne_results.shape[0]):
#     plt.text(tsne_results[i, 0], tsne_results[i, 1], str(y[i]),
#              color=colours[int(y[i])],
#              fontdict={'weight': 'bold', 'size':50})
# plt.xticks([])
# plt.yticks([])
# plt.axis('off')
# plt.show()

# %% [markdown]
# 4. Do you think t-SNE solution is satisfactory? Can you distinguish between different classes easily? Which one has done a better job: t-SNE or the PCA you applied in the assignment of the previous checkpoint?

# %%
plt.figure(figsize=(10,5))
plt.scatter(tsne_results[:, 0], tsne_results[:, 1])
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.show()

# %% [markdown]
# By using t-SNE, we can distinguish some classes clearly and in this respect t-SNE solution is better than that of PCA's.

# %% [markdown]
# 5. Now, play with the different perplexity values and apply t-SNE for each of them. Which perplexity value is the best one in terms of the two-dimensional representation clarity?

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=10, n_iter=250)
tsne_results = tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 6.850s...
# [t-SNE] Computed neighbors for 10000 samples in 295.558s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.427289
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 86.770973
# [t-SNE] KL divergence after 251 iterations: .000000

# %%
plt.figure(figsize=(10,5))
plt.title('t-SNE with perplexity=10')
plt.scatter(tsne_results[:, 0], tsne_results[:, 1])
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.show()

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=30, n_iter=250)
tsne_results = tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 6.106s...
# [t-SNE] Computed neighbors for 10000 samples in 297.537s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.764664
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.701080
# [t-SNE] KL divergence after 251 iterations: .000000

# %%
plt.figure(figsize=(10, 5))
plt.title('t-sne with perplexity=30')
plt.scatter(tsne_results[:, 0], tsne_results[:, 1])
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.show()

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=250)
tsne_results = tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 7.730s...
# [t-SNE] Computed neighbors for 10000 samples in 306.639s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.919358
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.871109
# [t-SNE] KL divergence after 251 iterations: .000000

# %%
plt.figure(figsize=(10,5))
plt.title('t-sne with perplexity=50')
plt.scatter(tsne_results[:, 0], tsne_results[:, 1])
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.show()

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=60, n_iter=250)
tsne_results = tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 181 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 7.250s...
# [t-SNE] Computed neighbors for 10000 samples in 300.712s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.976610
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.524727
# [t-SNE] KL divergence after 251 iterations: .000000

# %%
plt.figure(figsize=(10,5))
plt.title('t-sne with perplexity=60')
plt.scatter(tsne_results[:, 0], tsne_results[:, 1])
plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.show()

# %% [markdown]
# All the different configurations of perplexity achieves better results than PCA, however choosing one of them isn't that much easy by just looking at unlabeled and uncolored graphs
