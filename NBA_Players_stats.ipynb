# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaukhar-ai/for_my_Thinkful_work/blob/master/NBA_Players_stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Day 47 Lecture 1 Assignment
#
# In this assignment, we will apply k-means clustering to a dataset containing player-season statistics for NBA players from the past four years.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# This dataset contains player-season statistics for NBA players from the past four years. Each row in this dataset represents a player's per-game averages for a single season.
#
# This dataset contains the following variables:
#
# - Seas: season ('2019' = 2018-2019 season, '2018' = 2017-2018 season, etc.)
# - Player: player name
# - Pos: position
# - Age: age
# - Tm: team
# - G: games played
# - GS: games started
# - MP: minutes played
# - FG: field goals
# - FGA: field goals attempted
# - FG%: field goal percentage
# - 3P: 3 pointers
# - 3PA: 3 pointers attempted
# - 3P%: 3 point percentage
# - 2P: 2 pointers
# - 2PA: 2 pointers attempted
# - 2P%: 2 point percentage
# - eFG%: effective field goal percentage
# - FT: free throws
# - FTA: free throws attempted
# - FT%: free throw percentage
# - ORB: offensive rebound
# - DRB: defensive rebound
# - TRB: total rebounds
# - AST: assists
# - STL: steals
# - BLK: blocks
# - TOV: turnovers
# - PF: personal fouls
# - PTS: points
#
# Load the dataset.

# %%
# answer goes here
df = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/Data%20Sets%20Clustering/nba_player_seasons.csv')
df.head()
# Out:
#    Seas        Player Pos  Age   Tm   G  GS  ...  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2019  Álex Abrines  SG   25  OKC  31   2  ...  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1  2019    Quincy Acy  PF   28  PHO  10   0  ...  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2  2019  Jaylen Adams  PG   22  ATL  34   1  ...  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3  2019  Steven Adams   C   25  OKC  80  80  ...  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4  2019   Bam Adebayo   C   21  MIA  82  28  ...  7.3  2.2  0.9  0.8  1.5  2.5   8.9
#
# [5 rows x 30 columns]

# %% [markdown]
# The goal is to cluster these player-seasons to identify potential player "archetypes".
#
# Begin by removing players whose season did not meet one of the following criteria:
# 1. Started at least 20 games
# 2. Averaged at least 10 minutes per game

# %%
# answer goes here
df = df[df['G']>=20]
df = df[df['MP']>=10]
df.head()
# Out:
#    Seas             Player Pos  Age   Tm   G  ...  AST  STL  BLK  TOV   PF   PTS
# 0  2019       Álex Abrines  SG   25  OKC  31  ...  0.6  0.5  0.2  0.5  1.7   5.3
# 2  2019       Jaylen Adams  PG   22  ATL  34  ...  1.9  0.4  0.1  0.8  1.3   3.2
# 3  2019       Steven Adams   C   25  OKC  80  ...  1.6  1.5  1.0  1.7  2.6  13.9
# 4  2019        Bam Adebayo   C   21  MIA  82  ...  2.2  0.9  0.8  1.5  2.5   8.9
# 7  2019  LaMarcus Aldridge   C   33  SAS  81  ...  2.4  0.5  1.3  1.8  2.2  21.3
#
# [5 rows x 30 columns]

# %% [markdown]
# Choose a subset of numeric columns that is interesting to you from an "archetypal" standpoint.
#
# We will choose the following basic statistics: **points, total rebounds, assists, steals, blocks**, and **turnovers**, but you should feel free to choose other reasonable feature sets if you like. Be careful not to include too many dimensions (curse of dimensionality).

# %%
# answer goes here
cols = ["PTS", "TRB", "AST", "STL", "BLK", "TOV", "Age"]
df = df[cols]
df.head()
# Out:
#     PTS  TRB  AST  STL  BLK  TOV  Age
# 0   5.3  1.5  0.6  0.5  0.2  0.5   25
# 2   3.2  1.8  1.9  0.4  0.1  0.8   22
# 3  13.9  9.5  1.6  1.5  1.0  1.7   25
# 4   8.9  7.3  2.2  0.9  0.8  1.5   21
# 7  21.3  9.2  2.4  0.5  1.3  1.8   33

# %% [markdown]
# Standardize the features in your dataset using scikit-learn's StandardScaler, which will set the mean of each feature to 0 and the variance to 1.

# %%
# answer goes here
scaler = StandardScaler()
scaled = scaler.fit_transform(df)

# %% [markdown]
# Run K-means clustering with K = 3 and print out the resulting centroids. When printing the centroids, transform the scaled centroids back into their corresponding unscaled values. What "archetypes" do you see?

# %%
# answer goes here

k_means = KMeans(n_clusters=3)
k_means.fit(scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# Experiment with different values of K. Do any further interesting archetypes come out?

# %%
pd.DataFrame(k_means.cluster_centers_, columns=df.columns)
# Out:
#         PTS       TRB       AST       STL       BLK       TOV       Age
# 0 -0.517289 -0.493578 -0.366520 -0.404732 -0.381467 -0.508706  0.062153
# 1  0.499004  1.303237 -0.197550  0.256497  1.215776  0.306930 -0.170472
# 2  1.421837  0.228183  1.759356  1.295188 -0.108191  1.649011 -0.020051

# %%
df = pd.DataFrame(scaler.inverse_transform(k_means.cluster_centers_), columns=df.columns)
df.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col0,#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col1,#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col2,#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col3,#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col4,#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col5,#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col6{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col6,#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col1,#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col4,#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col0,#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col2,#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col3,#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col0{
#             background-color:  #67a4cc;
#             color:  #000000;
#         }#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col2{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col3{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col5{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col1{
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col4{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col6{
#             background-color:  #2d8abd;
#             color:  #000000;
#         }</style><table id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PTS</th>        <th class="col_heading level0 col1" >TRB</th>        <th class="col_heading level0 col2" >AST</th>        <th class="col_heading level0 col3" >STL</th>        <th class="col_heading level0 col4" >BLK</th>        <th class="col_heading level0 col5" >TOV</th>        <th class="col_heading level0 col6" >Age</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col0" class="data row0 col0" >7.132769</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col1" class="data row0 col1" >2.992530</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col2" class="data row0 col2" >1.547709</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col3" class="data row0 col3" >0.576793</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col4" class="data row0 col4" >0.300100</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col5" class="data row0 col5" >0.907570</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row0_col6" class="data row0 col6" >26.835657</td>
#             </tr>
#             <tr>
#                         <th id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col0" class="data row1 col0" >12.873887</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col1" class="data row1 col1" >7.294659</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col2" class="data row1 col2" >1.852226</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col3" class="data row1 col3" >0.838576</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col4" class="data row1 col4" >0.983383</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col5" class="data row1 col5" >1.532938</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row1_col6" class="data row1 col6" >25.845697</td>
#             </tr>
#             <tr>
#                         <th id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col0" class="data row2 col0" >18.087045</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col1" class="data row2 col1" >4.720648</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col2" class="data row2 col2" >5.378947</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col3" class="data row2 col3" >1.249798</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col4" class="data row2 col4" >0.417004</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col5" class="data row2 col5" >2.561943</td>
#                         <td id="T_faf3a5e8_02d4_11eb_ad0c_0242ac1c0002row2_col6" class="data row2 col6" >26.485830</td>
#             </tr>
#     </tbody></table>

# %%
# answer goes here
k_means = KMeans(n_clusters=5)
k_means.fit(scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
df = pd.DataFrame(scaler.inverse_transform(k_means.cluster_centers_), columns=df.columns)
df.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col0{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col1{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col2{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col3{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col4,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row4_col0,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row4_col1,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row4_col2,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row4_col3,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row4_col4,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row4_col5,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row4_col6{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col5{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col6,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col1,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col4,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col0,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col2,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col3,#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col0{
#             background-color:  #75a9cf;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col2{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col3{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col5{
#             background-color:  #9fbad9;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col6{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col0{
#             background-color:  #81aed2;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col1{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col2{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col3{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col4{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col5{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col6{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col1{
#             background-color:  #7eadd1;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col4{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col6{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }</style><table id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PTS</th>        <th class="col_heading level0 col1" >TRB</th>        <th class="col_heading level0 col2" >AST</th>        <th class="col_heading level0 col3" >STL</th>        <th class="col_heading level0 col4" >BLK</th>        <th class="col_heading level0 col5" >TOV</th>        <th class="col_heading level0 col6" >Age</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col0" class="data row0 col0" >7.218579</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col1" class="data row0 col1" >3.201639</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col2" class="data row0 col2" >1.572404</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col3" class="data row0 col3" >0.573497</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col4" class="data row0 col4" >0.326230</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col5" class="data row0 col5" >0.915301</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row0_col6" class="data row0 col6" >31.792350</td>
#             </tr>
#             <tr>
#                         <th id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col0" class="data row1 col0" >13.068692</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col1" class="data row1 col1" >8.214486</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col2" class="data row1 col2" >1.833645</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col3" class="data row1 col3" >0.766822</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col4" class="data row1 col4" >1.215888</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col5" class="data row1 col5" >1.607477</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row1_col6" class="data row1 col6" >25.780374</td>
#             </tr>
#             <tr>
#                         <th id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col0" class="data row2 col0" >12.628571</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col1" class="data row2 col1" >3.958333</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col2" class="data row2 col2" >2.919940</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col3" class="data row2 col3" >0.976786</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col4" class="data row2 col4" >0.328274</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col5" class="data row2 col5" >1.581845</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row2_col6" class="data row2 col6" >25.625000</td>
#             </tr>
#             <tr>
#                         <th id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col0" class="data row3 col0" >20.028387</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col1" class="data row3 col1" >5.450323</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col2" class="data row3 col2" >6.209677</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col3" class="data row3 col3" >1.384516</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col4" class="data row3 col4" >0.503871</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col5" class="data row3 col5" >2.911613</td>
#                         <td id="T_ffe545b6_02d4_11eb_ad0c_0242ac1c0002row3_col6" class="data row3 col6" >26.625806</td>
#             </tr>
#             <tr>
