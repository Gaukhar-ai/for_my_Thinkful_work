# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy import mean
import seaborn as sns

# %matplotlib inline

# %%
def reverse(a):
    str = ""
    for i in a:
        str = i + str
    return str

# %%
a = 'IloveTraveling'

# %%
print("the original string is: ",end="")
print(a)
# Out:
# the original string is: IloveTraveling

# %%
print("The reversed string(using loops) is: ",end="")
print(reverse(a))
# Out:
# The reversed string(using loops) is: gnilevarTevolI

# %% [markdown]
# Complete the function below that can be used to calculate and return the posterior probability of an event A, given the known outcome of Event B using Bayes Theorem:
# def bayes(a, b_given_a, b_given_not_a):
#
#     """
#     Calculates P(A | B) using bayes theorem.
#
#     Args:
#         a: P(A)
#         b_given_a: P(B | A)
#         b_given_not_a: P(B | ~A)
#
#     Returns:
#         P(A | B)
#     """

# %%
#bayes theorem: P(A|B) = P(B|A)*P(A)) / P(B)
    # calculating prob of not A n_a = 1 - a 
    # calculating prob of b prob_b = b_given_a * a + b_given_not_a * n_a
    # calculating prob of a given b prob_a_giv_b =(b_given_a*a,)/prob_b return prob_a_giv_b

def bayes(a, b_given_a, b_given_not_a):
    post_prob = (b_given_a * a) / ((b_given_a * a) + b_given_not_a * (1 - a))
    return post_prob

print(bayes(0.9, 3.5, 7))
# Out:
# 0.8181818181818182

# %% [markdown]
# Analyze the teams dataset from the Lahman baseball records. This dataset contains season statistics for each Major League Baseball team.
#
# a. For all records since 1995, plot histograms for the following variables. Which distribution do they appear to follow? Consider what each variable is measuring along with the histogram's shape.
#
#  - Stolen bases per game
#  - Wins
#  - Earned run average
# b. Conduct some further exploratory data analysis on this dataset. Consider qualities like distributions, correlations and trends over time. Try to find something interesting to say about the data, and use visualizations to support your argument.
#
# Choose any two of the variables from 3. Draw 1,000 samples, taking the mean of 100 observations each time. Plot the frequencies of the sample means. What distribution does this appear to follow?

# %%
url = 'https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/lahman-teams.csv'
baseball_team = pd.read_csv(url)

# %%
baseball_team.head(2)
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP    FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ... NaN  0.83
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ... NaN  0.82
#
#                       name                     park  attendance  BPF  PPF  \
# 0     Boston Red Stockings      South End Grounds I         NaN  103   98
# 1  Chicago White Stockings  Union Base-Ball Grounds         NaN  104  102
#
#    teamIDBR  teamIDlahman45  teamIDretro
# 0       BOS             BS1          BS1
# 1       CHI             CH1          CH1
#
# [2 rows x 48 columns]

# %%
#baseball_team.info()

# %%
baseball_team_95 = baseball_team.loc[baseball_team["yearID"] >= 1995]
baseball_team_95.head(2)
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome   W   L  ...     DP  \
# 2181    1995   NL    ATL      ATL     E     1  144   72.0  90  54  ...  113.0
# 2182    1995   AL    BAL      BAL     E     3  144   72.0  71  73  ...  141.0
#
#         FP               name                           park  attendance  BPF  \
# 2181  0.98     Atlanta Braves  Atlanta-Fulton County Stadium   2561831.0  103
# 2182  0.98  Baltimore Orioles    Oriole Park at Camden Yards   3098475.0  102
#
#       PPF  teamIDBR  teamIDlahman45  teamIDretro
# 2181  102       ATL             ATL          ATL
# 2182  101       BAL             BAL          BAL
#
# [2 rows x 48 columns]

# %%
baseball_team_95['SB_per_game'] = baseball_team_95['SB'] / baseball_team_95['G']
# Out:
# <ipython-input-11-7cf1c7ad8dcb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   baseball_team_95['SB_per_game'] = baseball_team_95['SB'] / baseball_team_95['G']

# %%
plt.hist(baseball_team_95['SB_per_game'])
# Out:
# (array([ 19.,  87., 127., 145., 102.,  74.,  43.,  18.,   4.,   5.]),
#  array([0.19135802, 0.30416667, 0.41697531, 0.52978395, 0.64259259,
#         0.75540123, 0.86820988, 0.98101852, 1.09382716, 1.2066358 ,
#         1.31944444]),
#  <BarContainer object of 10 artists>)

# %%
#bases stolen
#baseball_team_95.SB.hist()
#plt.xlabel("Frequency")
#plt.ylabel("Bases Stolen")
#plt.title("Bases stolen by team per year since 1995")
#plt.show()

# %%
#wins
#baseball_team_95.W.hist()
#plt.xlabel("Wins")
#plt.ylabel("Wins by team per year since 1995")
#plt.title("Frequency")
#plt.show()

# %%
plt.hist(baseball_team_95['W'])
# Out:
# (array([  1.,  13.,  32., 120., 131., 118., 127.,  71.,   9.,   2.]),
#  array([ 43. ,  50.3,  57.6,  64.9,  72.2,  79.5,  86.8,  94.1, 101.4,
#         108.7, 116. ]),
#  <BarContainer object of 10 artists>)

# %%
# Earnings
#baseball_team_95.ERA.hist()
#plt.xlabel("ERA")
#plt.ylabel("Frequency")
#plt.title("Earned Run Average (ERA) stolen by each team per year since 1995")
#plt.show()

# %%
plt.hist(baseball_team_95['ERA'])
# Out:
# (array([ 16.,  56., 103., 156., 126., 100.,  47.,  16.,   3.,   1.]),
#  array([2.94 , 3.284, 3.628, 3.972, 4.316, 4.66 , 5.004, 5.348, 5.692,
#         6.036, 6.38 ]),
#  <BarContainer object of 10 artists>)

# %%
baseball_team_95.corr()
# Out:
#                yearID      Rank         G     Ghome         W         L  \
# yearID       1.000000  0.022269  0.367340  0.365277  0.060672  0.060867
# Rank         0.022269  1.000000  0.016677 -0.006942 -0.863998  0.872770
# G            0.367340  0.016677  1.000000  0.968998  0.172994  0.151331
# Ghome        0.365277 -0.006942  0.968998  1.000000  0.185547  0.128816
# W            0.060672 -0.863998  0.172994  0.185547  1.000000 -0.947283
# L            0.060867  0.872770  0.151331  0.128816 -0.947283  1.000000
# R           -0.385195 -0.442457  0.132309  0.136794  0.519126 -0.478956
# AB           0.195462 -0.050315  0.849826  0.830716  0.227550  0.047664
# H           -0.223833 -0.278540  0.326821  0.331353  0.375258 -0.270889
# 2B          -0.050959 -0.163972  0.297314  0.297788  0.276727 -0.181546
# 3B          -0.055852  0.081306  0.020237  0.019538 -0.091049  0.098466
# HR          -0.174619 -0.348000  0.142903  0.139937  0.415217 -0.371241
# BB          -0.344209 -0.371190  0.070091  0.072331  0.414375 -0.394230
# SO           0.541902  0.146420  0.309415  0.304592 -0.077485  0.179989
# SB          -0.162413 -0.058184 -0.040374 -0.033340  0.058896 -0.072923
# CS          -0.405249  0.065425 -0.079086 -0.084041 -0.089534  0.063769
# HBP         -0.204524 -0.121507 -0.020682 -0.009773  0.161396 -0.163465
# SF          -0.262328 -0.253320  0.086856  0.060635  0.298843 -0.297095
# RA          -0.365774  0.517089  0.111120  0.100593 -0.568780  0.606007
# BPF         -0.043680 -0.062067  0.121723  0.076003    0.153190  1.000000
# PPF         -0.101230 -0.009156  0.157057  0.036888    0.062770  0.981948
# SB_per_game -0.056019  0.095881 -0.081907 -0.189416   -0.038981 -0.002617
#
#                   PPF  SB_per_game
# yearID      -0.007964    -0.191151
# Rank         0.095079    -0.059743
# G           -0.006137    -0.124072
# Ghome       -0.014100    -0.114627
# W           -0.079277     0.044884
# L            0.077916    -0.086026
# R            0.228502     0.058200
# AB           0.101674    -0.114381
# H            0.247813     0.021327
# 2B           0.203106    -0.136193
# 3B           0.212563     0.170317
# HR           0.222599    -0.117590
# BB          -0.082604     0.029013
# SO          -0.019313    -0.102584
# SB          -0.012073     0.996133
# CS           0.023051     0.621445
# HBP          0.006564    -0.046280
# SF           0.041755     0.135270
# RA           0.276062    -0.028187
# ER           0.293277    -0.034633
# ERA          0.300809    -0.015473
# CG          -0.050368     0.148025
# SHO         -0.211347    -0.040872
# SV          -0.145225     0.021803
# IPouts      -0.080024    -0.095755
# HA           0.273245    -0.066060
# HRA          0.255298     0.019772
# BBA          0.088377     0.016907
# SOA         -0.101230    -0.056019
# E           -0.009156     0.095881
# DP           0.157057    -0.081907
# FP           0.036888    -0.189416
# attendance   0.062770    -0.038981
# BPF          0.981948    -0.002617
# PPF          1.000000    -0.011834
# SB_per_game -0.011834     1.000000
#
# [36 rows x 36 columns]

# %%
y_ID_attend = baseball_team_95 ['yearID'].corr(baseball_team_95['attendance'])
print (y_ID_attend)
# Out:
# 0.1603229006363417

# %%
avg = baseball_team['attendance'].mean()
avg
# Out:
# 1344345.530482977

# %%
med = baseball_team['attendance'].median()
med
# Out:
# 1140347.5

# %%
plt.hist(baseball_team['attendance'])
plt.show()

# %%
sns.distplot(baseball_team["attendance"])
plt.show()

# %% [markdown]
# #4 Analyze the teams dataset from the Lahman baseball records. This dataset contains season statistics for each Major League Baseball team.
#
# a. For all records since 1995, plot histograms for the following variables. Which distribution do they appear to follow? Consider what each variable is measuring along with the histogram's shape.
#
# Stolen bases per game
# Wins
# Earned run average b. Conduct some further exploratory data analysis on this dataset. Consider qualities like distributions, correlations and trends over time. Try to find something interesting to say about the data, and use visualizations to support your argument.
# Choose any two of the variables from 3. Draw 1,000 samples, taking the mean of 100 observations each time. Plot the frequencies of the sample means. What distribution does this appear to follow?

# %%
choice = []
for i in range(1,1000):
    wins_baseball_team = baseball_team['W'].sample(n=100)
    wins_aver = wins_baseball_team.mean()
    choice.append(wins_aver)

# %%
chart = pd.DataFrame({'wins_baseball_team' : choice})
chart.plot()
# Out:
# <AxesSubplot:>

# %%
choices = []
for i in range(1,1000):
    ERA_baseball_team = baseball_team['ERA'].sample(n=100)
    ERA_aver = ERA_baseball_team.mean()
    choices.append(ERA_aver)

# %%
charts = pd.DataFrame({'ERA' : choice})
charts.plot()
# Out:
# <AxesSubplot:>

# %%
means = [mean(baseball_team_95['ERA'].sample(n=50)) for i in range(1000)]
plt.hist(means)
plt.xlabel('earned run average')
plt.show()

# %%
means = [mean(baseball_team_95['W'].sample(n=50)) for i in range(1000)]
plt.hist(means)
plt.xlabel("wins mean")
plt.show()

# %% [markdown]
# Wins and Earned run average follow a normal distribution. They're approximately symmetrical, bell shaped.
